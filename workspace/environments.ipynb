# %% [markdown]
# # 環境情報
#
# `tensorflow/tensorflow:2.4.1-gpu`のDockerコンテナをベースに、必要なパッケージを追加している。
# 詳細は`docker-compose.yml`や`Dockerfile`を参照。

# %%
import platform

print(f"Platform: {platform.platform()}")
print(f"Machine : {platform.machine()}")
print(f"Python  : {platform.python_version()}")
# Out:
# Platform: Linux-5.4.72-microsoft-standard-WSL2-x86_64-with-Ubuntu-18.04-bionic
# Machine : x86_64
# Python  : 3.6.9

# %%
# !env
# Out:
# MPLBACKEND=module://ipykernel.pylab.backend_inline
# HOSTNAME=543644a365df
# LD_LIBRARY_PATH=/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# MKL_DEBUG_CPU_TYPE=5
# HOME=/root
# PAGER=cat
# CUDA_VERSION=11.0.3
# NVIDIA_REQUIRE_CUDA=cuda>=11.0 brand=tesla,driver>=418,driver<419 brand=tesla,driver>=440,driver<441 brand=tesla,driver>=450,driver<451
# NVIDIA_DRIVER_CAPABILITIES=compute,utility
# TERM=xterm-color
# PATH=/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# LANG=C.UTF-8
# GIT_PAGER=cat
# CLICOLOR=1
# PWD=/workspace
# JPY_PARENT_PID=1
# NVIDIA_VISIBLE_DEVICES=all
# TZ=Asia/Tokyo

# %%
# !pip freeze > requires.txt
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# absl-py                   0.11.0
# anyio                     2.2.0
# appdirs                   1.4.4
# argon2-cffi               20.1.0
# asn1crypto                0.24.0
# astunparse                1.6.3
# async-generator           1.10
# attrs                     20.3.0
# audioread                 2.1.9
# Babel                     2.9.0
# backcall                  0.2.0
# black                     20.8b1
# bleach                    3.3.0
# cachetools                4.2.0
# certifi                   2020.12.5
# cffi                      1.14.5
# chardet                   4.0.0
# click                     7.1.2
# contextvars               2.4
# cryptography              2.1.4
# cycler                    0.10.0
# dataclasses               0.8
# decorator                 5.0.7
# defusedxml                0.7.1
# deprecation               2.1.0
# entrypoints               0.3
# ...
